# %%
import pandas as pd
pd.options.mode.chained_assignment = None 
import numpy as np
import scipy
import seaborn as sns
import matplotlib.pyplot as plt
import os
os.chdir("..")
from functools import reduce
from statsmodels.tsa.stattools import coint
from statsmodels.regression.rolling import RollingOLS
from pykalman import KalmanFilter
import statsmodels.api as sm
import ffn
from STRATEGY.BaseTradeEngine import BaseTradeEngine
sns.set(style='white')
import sys
import importlib
import warnings
from STRATEGY.BaseTradeEngine import BaseTradeEngine
from STRATEGY.Benchmark import Benchmark
from STRATEGY.Kalman import Kalman
importlib.reload(sys.modules['STRATEGY.BaseTradeEngine'])
from STRATEGY.BaseTradeEngine import BaseTradeEngine
importlib.reload(sys.modules['STRATEGY.Benchmark'])
from STRATEGY.Benchmark import Benchmark
importlib.reload(sys.modules['STRATEGY.Kalman'])
from STRATEGY.Kalman import Kalman
from UTIL import tradeUtil as tu
# Out:
# /Users/Ferni/opt/anaconda3/lib/python3.7/site-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
#http://www.thealgoengineer.com/2014/online_linear_regression_kalman_filter/ plots

# %%
odr = ['rya','ulvr','bpln','hsbcln']
adr = ['ryaay','ul','bp','hsbc']
name = ['Ryanair','Unilever','BP','HSBC']
treatment  = {'rm_outliers': False, 'rm_wide_spread': False,  'adjust_spread': False}

# %%
#cointegration p_value
for pair in range(4):
    a = pd.read_csv('STATICS/PRICE/'+odr[pair]+'.csv', index_col = 'date' )
    b = pd.read_csv('STATICS/PRICE/'+adr[pair]+'.csv', index_col = 'date' )
    x, y = BaseTradeEngine.clean_data(a, b, 'last', **treatment)
    print(name[pair]+": "+str(coint(x['last'],y['last'], trend='c')[1]))
# Out:
# Ryanair: 0.2902906473827319
# Unilever: 1.4853392960882666e-06
# BP: 9.64751954208428e-09
# HSBC: 0.0005515556725417441

# %%
# Cointegration throughout the sample
pair = 0
a = pd.read_csv('STATICS/PRICE/'+odr[pair]+'.csv', index_col = 'date' )
b = pd.read_csv('STATICS/PRICE/'+adr[pair]+'.csv', index_col = 'date' )
x, y = BaseTradeEngine.clean_data(a, b, 'last', **treatment)
df = pd.concat([x['last'], y['last']], axis=1)
df.columns = ['odr','adr']
df['ii'] = range(len(df))
#windows =  df['ii'].rolling(1000).apply(lambda ii: (ii.index))


list_of_indexes=[]
df['ii'].rolling(7500).apply((lambda x: list_of_indexes.append(x.tolist()) or 0), raw=False)

p_vals = []
timestamps = []
for idx in list_of_indexes[::2500]:
    rows = df['ii'].isin(idx)
    p_vals.append(coint(df.loc[rows, 'adr'], df.loc[rows, 'odr'],trend='ct')[1])
    timestamps.append(df.index[int(idx[-1])])
pd.DataFrame({'p_value': p_vals}, index = timestamps).plot()

# %%
first  = []
second = []

for change in range(6000,12000,500):
    first.append(coint(df.adr[0:change], df.odr[0:change],trend='ct')[1])
    second.append(coint(df.adr[change:27152], df.odr[change:27152],trend='ct')[1])
pd.DataFrame({'Pre': first, 'Post': second, '5%': 0.05}, index= df.index[df.ii.isin(range(6000,12000,500))]).plot()

# %%
#Descriptive statistics

rate = [5,1,6,5]


for pair in range(4):
    a = pd.read_csv('STATICS/PRICE/'+odr[pair]+'.csv'  , index_col = 'date' )
    b = pd.read_csv('STATICS/PRICE/'+adr[pair]+'.csv', index_col = 'date' )
    #print(a['last'].describe())
    #print(b['last'].describe())
    x, y = BaseTradeEngine.clean_data(a, b, 'last', **treatment)
    S=y-np.multiply(rate[pair],x)
    #print(S['last'].describe())
    S.loc[::20,['bid','ask','last']].plot(title=name[pair])

# %%
# Kalman Ryanair performance with different resampling rates
a = pd.read_csv('STATICS/PRICE/rya.csv'  , index_col = 'date' )
b = pd.read_csv('STATICS/PRICE/ryaay.csv', index_col = 'date' )
#x, y = BaseTradeEngine.clean_data(x, y, 'last', rm_outliers = True)
for r in [1,25,50,100]:
    default = {'lag': 0, 'resample': r, 'rounding': 3, 'entryMult': 3, 'exitMult': -1.5, 'transaction_cost': 0.0063}
    treatment  = {'rm_outliers': True, 'rm_wide_spread': True, 'max_width': 20, 'adjust_spread': True, 'adjust_width': 10}

    x, y = BaseTradeEngine.clean_data(a, b, 'last', **treatment)

    eng = Kalman(x, y, 'last','bid','ask', is_cleaned = True, **default)
    eng.process(train_rng = [0.75,1],**default)
    eng.get_summary(verbose=True)
# Out:
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# |    |   sharpe_ratio |   long_ret |   short_ret |   spread_ret |   trans_ret |   n_transactions |   mean_hold_time |
# |----+----------------+------------+-------------+--------------+-------------+------------------+------------------|
# |  0 |         -1.115 |      0.983 |       1.007 |        0.992 |       0.999 |                8 |             8634 |
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# Stats for cum rets from 2019-10-29 14:56:00 - 2020-03-27 15:41:00
# Annual risk-free rate considered: 0.16%
# Summary:
# Total Return      Sharpe  CAGR    Max Drawdown
# --------------  --------  ------  --------------
# -1.79%             -1.12  -4.30%  -4.25%
#
# Annualized Returns:
# mtd     3m      6m    ytd     1y    3y      5y    10y    incep.
# ------  ------  ----  ------  ----  ------  ----  -----  --------
# -2.82%  -2.45%  -     -2.39%  -     -4.30%  -     -      -4.30%
#
# Periodic:
#         daily    monthly    yearly
# ------  -------  ---------  --------
# sharpe  -1.12    -0.89      -
# mean    -4.46%   -4.22%     -2.39%
# vol     4.14%    4.92%      -
# skew    0.42     -1.94      -
# kurt    7.41     3.99       -
# best    1.25%    0.67%      -2.39%
# worst   -0.92%   -2.82%     -2.39%
#
# Drawdowns:
# max     avg       # days
# ------  ------  --------
# -4.25%  -1.67%        31
#
# Misc:
# ---------------  ------
# avg. up month    0.59%
# avg. down month  -0.98%
# up year %        0.00%
# 12m up %         -
# ---------------  ------
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# |    |   sharpe_ratio |   long_ret |   short_ret |   spread_ret |   trans_ret |   n_transactions |   mean_hold_time |
# |----+----------------+------------+-------------+--------------+-------------+------------------+------------------|
# |  0 |          0.482 |          1 |       1.032 |        0.983 |       0.998 |               27 |             6770 |
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# Stats for cum rets from 2019-10-29 15:35:00 - 2020-03-27 15:35:00
# Annual risk-free rate considered: 0.16%
# Summary:
# Total Return      Sharpe  CAGR    Max Drawdown
# --------------  --------  ------  --------------
# 1.15%               0.48  2.82%   -3.17%
#
# Annualized Returns:
# mtd     3m      6m    ytd     1y    3y     5y    10y    incep.
# ------  ------  ----  ------  ----  -----  ----  -----  --------
# -1.23%  -0.43%  -     -0.33%  -     2.82%  -     -      2.82%
#
# Periodic:
#         daily    monthly    yearly
# ------  -------  ---------  --------
# sharpe  0.48     0.86       -
# mean    3.06%    3.05%      -0.33%
# vol     6.02%    3.36%      -
# skew    0.47     -0.77      -
# kurt    2.57     1.52       -
# best    1.39%    1.40%      -0.33%
# worst   -1.27%   -1.23%     -0.33%
#
# Drawdowns:
# max     avg       # days
# ------  ------  --------
# -3.17%  -1.38%      26.6
#
# Misc:
# ---------------  ------
# avg. up month    0.63%
# avg. down month  -1.23%
# up year %        0.00%
# 12m up %         -
# ---------------  ------
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# |    |   sharpe_ratio |   long_ret |   short_ret |   spread_ret |   trans_ret |   n_transactions |   mean_hold_time |
# |----+----------------+------------+-------------+--------------+-------------+------------------+------------------|
# |  0 |          2.073 |      1.032 |       1.041 |        0.981 |       0.998 |               29 |             7191 |
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# Stats for cum rets from 2019-10-29 14:20:00 - 2020-03-27 15:10:00
# Annual risk-free rate considered: 0.16%
# Summary:
# Total Return      Sharpe  CAGR    Max Drawdown
# --------------  --------  ------  --------------
# 5.16%               2.07  13.00%  -1.91%
#
# Annualized Returns:
# mtd     3m     6m    ytd    1y    3y      5y    10y    incep.
# ------  -----  ----  -----  ----  ------  ----  -----  --------
# -0.03%  2.48%  -     2.58%  -     13.00%  -     -      13.00%
#
# Periodic:
#         daily    monthly    yearly
# ------  -------  ---------  --------
# sharpe  2.07     3.30       -
# mean    12.84%   11.00%     2.58%
# vol     6.12%    3.29%      -
# skew    0.02     0.85       -
# kurt    1.29     -0.51      -
# best    1.19%    2.32%      2.58%
# worst   -1.30%   -0.03%     2.58%
#
# Drawdowns:
# max     avg       # days
# ------  ------  --------
# -1.91%  -0.79%     13.33
#
# Misc:
# ---------------  -------
# avg. up month    1.15%
# avg. down month  -0.03%
# up year %        100.00%
# 12m up %         -
# ---------------  -------
# /Users/Ferni/opt/anaconda3/lib/python3.7/site-packages/ffn/core.py:2056: RuntimeWarning: divide by zero encountered in true_divide
#   res = np.divide(er.mean(), std)
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# |    |   sharpe_ratio |   long_ret |   short_ret |   spread_ret |   trans_ret |   n_transactions |   mean_hold_time |
# |----+----------------+------------+-------------+--------------+-------------+------------------+------------------|
# |  0 |           1.63 |      1.017 |       1.038 |        0.987 |       0.998 |               21 |             9519 |
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# Stats for cum rets from 2019-10-29 14:20:00 - 2020-03-27 14:20:00
# Annual risk-free rate considered: 0.16%
# Summary:
# Total Return      Sharpe  CAGR    Max Drawdown
# --------------  --------  ------  --------------
# 3.98%               1.63  9.98%   -1.65%
#
# Annualized Returns:
# mtd    3m     6m    ytd    1y    3y     5y    10y    incep.
# -----  -----  ----  -----  ----  -----  ----  -----  --------
# 0.68%  2.47%  -     2.52%  -     9.98%  -     -      9.98%
#
# Periodic:
#         daily    monthly    yearly
# ------  -------  ---------  --------
# sharpe  1.63     6.14       -
# mean    10.03%   8.77%      2.52%
# vol     6.05%    1.40%      -
# skew    0.20     1.75       -
# kurt    1.67     3.35       -
# best    1.14%    1.42%      2.52%
# worst   -1.29%   0.40%      2.52%
#
# Drawdowns:
# max     avg       # days
# ------  ------  --------
# -1.65%  -0.65%      9.83
#
# Misc:
# ---------------  -------
# avg. up month    0.73%
# avg. down month  -
# up year %        100.00%
# 12m up %         -
# ---------------  -------

# %%
# Why different resampling rates perform better
lowresample = {'lag': 0, 'resample': 1, 'rounding': 3, 'entryMult': 3, 'exitMult': -1.5, 'transaction_cost': 0.0063}
highresample = {'lag': 0, 'resample': 50, 'rounding': 3, 'entryMult': 3, 'exitMult': -1.5, 'transaction_cost': 0.0063}

treatment  = {'rm_outliers': True, 'rm_wide_spread': True, 'max_width': 20, 'adjust_spread': True, 'adjust_width': 10}

x, y = BaseTradeEngine.clean_data(a, b, 'last', **treatment)

low = Kalman(x, y, 'last','bid','ask', is_cleaned = True, **lowresample)
low.process(train_rng = [0.75,1],**lowresample)
high = Kalman(x, y, 'last','bid','ask', is_cleaned = True, **highresample)
high.process(train_rng = [0.75,1],**highresample)

# %%
low.plot_signals("2020-03-01","2020-04-25")
high.plot_signals("2020-03-01","2020-04-25")
# Out:
# -2.82 percent return in time window
# -0.03 percent return in time window

# %%
#Train performances with simple treatment setting for each data set 
odr = ['rya','ulvr','bpln','hsbcln']
adr = ['ryaay','ul','bp','hsbc']

settings =[{'lag': 0, 'resample': 20, 'rounding': 3, 'entryMult': 2.5, 'exitMult': -3, 'transaction_cost': 0.0063},
           {'lag': 0, 'resample': 10, 'rounding': 3, 'entryMult': 4, 'exitMult': -1, 'transaction_cost': 0.0063},
           {'lag': 0, 'resample': 20, 'rounding': 3, 'entryMult': 1, 'exitMult': -0.5, 'transaction_cost': 0.0063},
           {'lag': 1, 'resample': 10, 'rounding': 3, 'entryMult': 1, 'exitMult': 0, 'transaction_cost': 0.0063}]
         
treatment  = {'rm_outliers': True, 'rm_wide_spread': False,  'adjust_spread': False}
    
for pair in range(4):
    a = pd.read_csv('STATICS/PRICE/'+odr[pair]+'.csv'  , index_col = 'date' )
    b = pd.read_csv('STATICS/PRICE/'+adr[pair]+'.csv', index_col = 'date' )


    x, y = BaseTradeEngine.clean_data(a, b, 'last', **treatment)

    eng = Kalman(x, y, 'last','bid','ask', is_cleaned = True, **settings[pair])
    eng.process(train_rng = [0,0.75],**settings[pair])
    eng.get_summary(verbose=True)
# Out:
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# |    |   sharpe_ratio |   long_ret |   short_ret |   spread_ret |   trans_ret |   n_transactions |   mean_hold_time |
# |----+----------------+------------+-------------+--------------+-------------+------------------+------------------|
# |  0 |           1.62 |      1.109 |       1.099 |        0.938 |       0.993 |               81 |             5503 |
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# Stats for cum rets from 2018-07-25 13:40:00 - 2019-10-30 16:00:00
# Annual risk-free rate considered: 0.16%
# Summary:
# Total Return      Sharpe  CAGR    Max Drawdown
# --------------  --------  ------  --------------
# 13.53%              1.62  10.55%  -4.71%
#
# Annualized Returns:
# mtd    3m     6m     ytd    1y      3y      5y    10y    incep.
# -----  -----  -----  -----  ------  ------  ----  -----  --------
# 0.39%  1.42%  9.03%  6.34%  10.00%  10.55%  -     -      10.55%
#
# Periodic:
#         daily    monthly    yearly
# ------  -------  ---------  --------
# sharpe  1.62     1.74       -
# mean    10.45%   10.50%     6.34%
# vol     6.35%    5.95%      -
# skew    -0.27    -0.45      -
# kurt    1.89     -1.06      -
# best    1.26%    3.14%      6.34%
# worst   -1.82%   -2.31%     6.34%
#
# Drawdowns:
# max     avg       # days
# ------  ------  --------
# -4.71%  -0.96%     16.32
#
# Misc:
# ---------------  -------
# avg. up month    1.93%
# avg. down month  -1.23%
# up year %        100.00%
# 12m up %         100.00%
# ---------------  -------
# /Users/Ferni/opt/anaconda3/lib/python3.7/site-packages/ffn/core.py:2056: RuntimeWarning: divide by zero encountered in true_divide
#   res = np.divide(er.mean(), std)
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# |    |   sharpe_ratio |   long_ret |   short_ret |   spread_ret |   trans_ret |   n_transactions |   mean_hold_time |
# |----+----------------+------------+-------------+--------------+-------------+------------------+------------------|
# |  0 |          3.829 |      1.055 |       1.046 |        0.965 |       0.992 |               71 |             2183 |
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# Stats for cum rets from 2018-10-04 13:40:00 - 2019-11-20 15:30:00
# Annual risk-free rate considered: 0.16%
# Summary:
# Total Return      Sharpe  CAGR    Max Drawdown
# --------------  --------  ------  --------------
# 5.65%               3.83  4.99%   -0.26%
#
# Annualized Returns:
# mtd    3m     6m     ytd    1y     3y     5y    10y    incep.
# -----  -----  -----  -----  -----  -----  ----  -----  --------
# 0.00%  2.71%  4.19%  5.15%  5.15%  4.99%  -     -      4.99%
#
# Periodic:
#         daily    monthly    yearly
# ------  -------  ---------  --------
# sharpe  3.83     2.98       -
# mean    4.99%    4.82%      5.15%
# vol     1.26%    1.56%      -
# skew    2.85     0.94       -
# kurt    19.43    -0.29      -
# best    0.67%    1.23%      5.15%
# worst   -0.26%   0.00%      5.15%
#
# Drawdowns:
# max     avg       # days
# ------  ------  --------
# -0.26%  -0.07%      7.03
#
# Misc:
# ---------------  -------
# avg. up month    0.65%
# avg. down month  0.00%
# up year %        100.00%
# 12m up %         100.00%
# ---------------  -------
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# |    |   sharpe_ratio |   long_ret |   short_ret |   spread_ret |   trans_ret |   n_transactions |   mean_hold_time |
# |----+----------------+------------+-------------+--------------+-------------+------------------+------------------|
# |  0 |          1.414 |      1.025 |       1.038 |        0.975 |       0.995 |               29 |             9594 |
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# Stats for cum rets from 2018-07-25 13:40:00 - 2019-11-01 16:00:00
# Annual risk-free rate considered: 0.16%
# Summary:
# Total Return      Sharpe  CAGR    Max Drawdown
# --------------  --------  ------  --------------
# 3.21%               1.41  2.52%   -0.55%
#
# Annualized Returns:
# mtd    3m     6m     ytd    1y     3y     5y    10y    incep.
# -----  -----  -----  -----  -----  -----  ----  -----  --------
# 0.00%  0.98%  1.46%  1.34%  1.36%  2.52%  -     -      2.52%
#
# Periodic:
#         daily    monthly    yearly
# ------  -------  ---------  --------
# sharpe  1.41     2.35       -
# mean    2.55%    2.37%      1.34%
# vol     1.69%    0.94%      -
# skew    2.15     1.21       -
# kurt    18.41    2.89       -
# best    0.85%    0.94%      1.34%
# worst   -0.49%   -0.27%     1.34%
#
# Drawdowns:
# max     avg       # days
# ------  ------  --------
# -0.55%  -0.28%     25.31
#
# Misc:
# ---------------  -------
# avg. up month    0.29%
# avg. down month  -0.07%
# up year %        100.00%
# 12m up %         100.00%
# ---------------  -------
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# |    |   sharpe_ratio |   long_ret |   short_ret |   spread_ret |   trans_ret |   n_transactions |   mean_hold_time |
# |----+----------------+------------+-------------+--------------+-------------+------------------+------------------|
# |  0 |          1.812 |      1.027 |        1.04 |        0.978 |       0.993 |               43 |             2189 |
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# Stats for cum rets from 2018-07-25 13:40:00 - 2019-11-04 14:40:00
# Annual risk-free rate considered: 0.16%
# Summary:
# Total Return      Sharpe  CAGR    Max Drawdown
# --------------  --------  ------  --------------
# 3.81%               1.81  2.97%   -0.97%
#
# Annualized Returns:
# mtd    3m     6m     ytd    1y     3y     5y    10y    incep.
# -----  -----  -----  -----  -----  -----  ----  -----  --------
# 0.00%  0.38%  0.93%  0.79%  0.70%  2.97%  -     -      2.97%
#
# Periodic:
#         daily    monthly    yearly
# ------  -------  ---------  --------
# sharpe  1.81     1.18       -
# mean    3.00%    2.83%      0.79%
# vol     1.57%    2.27%      -
# skew    4.59     2.62       -
# kurt    37.54    7.62       -
# best    0.99%    2.35%      0.79%
# worst   -0.29%   -0.45%     0.79%
#
# Drawdowns:
# max     avg       # days
# ------  ------  --------
# -0.97%  -0.14%     31.54
#
# Misc:
# ---------------  -------
# avg. up month    0.63%
# avg. down month  -0.07%
# up year %        100.00%
# 12m up %         83.33%
# ---------------  -------

# %%
eng.plot_signals("2018-08-15","2018-09-15")
# Out:
# 0.48 percent return in time window

# %%
treatment1 = {'rm_outliers': True, 'rm_wide_spread': False, 'adjust_spread': False}

treatment2 = {'rm_outliers': True, 'rm_wide_spread': True, 'max_width': 10, 'adjust_spread': False}

treatment4 = {'rm_outliers': True, 'rm_wide_spread': True, 'max_width': 20, 'adjust_spread': True, 'adjust_width': 10}

settings1 = {'entryZ': 2, 'exitZ': -1, 'lag': 0, 'resample': 1, 'rounding': 2, 'windowZ':150, 'windowOLS':600,
          'transaction_cost':0.0063}

settings2 = {'entryZ': 2, 'exitZ': -1, 'lag': 0, 'resample': 1, 'rounding': 3, 'windowZ':10, 'windowOLS':600,
          'transaction_cost':0.0063}

settings4 = {'entryZ': 2, 'exitZ': 0, 'lag': 5, 'resample': 1, 'rounding': 1, 'windowZ':100, 'windowOLS':450,
          'transaction_cost':0.0063}

treatments = [treatment1,treatment2,treatment4]
settings = [settings1,settings2,settings4]
treatment = treatment1

pair = 0
a = pd.read_csv('STATICS/PRICE/'+odr[pair]+'.csv', index_col = 'date' )
b = pd.read_csv('STATICS/PRICE/'+adr[pair]+'.csv', index_col = 'date' )

rres = []

for i in range(3):
    
    x, y = BaseTradeEngine.clean_data(a, b, 'last', **treatments[i])
    df = pd.DataFrame({'y':y['last'],'x':x['last'],'c':1})

    windowOLS = int(min(max(settings[i]['windowOLS']/np.sqrt(settings[i]['resample']),
                            settings[i]['windowZ']),len(df)/2))

    model = RollingOLS(endog =df['y'], exog=df[['x','c']],window=windowOLS)
    rres.append(model.fit().params)

# %%
rres[0].columns = ["HR1","Intercept1"]
rres[1].columns = ["HR2","Intercept2"]
rres[2].columns = ["HR4","Intercept4"]
df = rres[0].merge(rres[1],left_index = True, right_index = True ).merge(rres[2],left_index = True, right_index = True )
df[["HR1","HR2","HR4"]].plot()
df[["Intercept1","Intercept2","Intercept4"]].plot()

# %%
treatment1 = {'rm_outliers': True, 'rm_wide_spread': False, 'adjust_spread': False}

treatment2 = {'rm_outliers': True, 'rm_wide_spread': True, 'max_width': 10, 'adjust_spread': False}

treatment4 = {'rm_outliers': True, 'rm_wide_spread': True, 'max_width': 20, 'adjust_spread': True, 'adjust_width': 10}

settings1 = {'entryMult': 2.5, 'exitMult': -3,   'lag': 0, 'resample': 20, 'rounding': 2, 'transaction_cost':0.0063}

settings2 = {'entryMult': 2.5, 'exitMult': -1.5, 'lag': 1, 'resample': 5,  'rounding': 3, 'transaction_cost':0.0063}

settings4 = {'entryMult': 4,   'exitMult': -1.5, 'lag': 0, 'resample': 1,  'rounding': 1, 'transaction_cost':0.0063}

settings = [settings1,settings2,settings4]
treatments = [treatment1,treatment2,treatment4]

pair = 0
a = pd.read_csv('STATICS/PRICE/'+odr[pair]+'.csv', index_col = 'date' )
b = pd.read_csv('STATICS/PRICE/'+adr[pair]+'.csv', index_col = 'date' )


kal_int = []
kal_hr  = []
for i in range(3):
    
    x, y = BaseTradeEngine.clean_data(a, b, 'last', **treatments[i])
    eng = Kalman(x, y, 'last','bid','ask', is_cleaned = True, **settings[i])
    kal_int.append(eng.intercept)
    kal_hr.append(eng.hr)

# %%
pd.DataFrame({'Slope': kal_hr[2],'Intercept':kal_int[2]}, index = x.index).plot()

# %%
a = x['last'].iloc[range(1,len(x),100)]
b = y['last'].iloc[range(1,len(x),100)]

cm = plt.cm.get_cmap('jet')
dates = [str(p.date()) for p in a.iloc[range(1,len(a),int(len(a)/10)+2)].index]
colors = np.linspace(0.1, 1, len(a))
sc = plt.scatter(a, b, s=50, c=colors, cmap=cm, edgecolor='k', alpha=0.7)
cb = plt.colorbar(sc)
cb.ax.set_yticklabels([str(p.date()) for p in a.iloc[range(1,len(a),int(len(a)/10)+2)].index])
plt.xlabel('rya')
plt.ylabel('ryaay')

# add regression lines
step = 200
xi = np.linspace(a.min(), a.max(), 20)

colors_l = np.linspace(0.1, 1, len(kal_hr[2][::step]))

for i, beta in enumerate(kal_hr[2][::step]):
    alpha = .2 if i <105 else 1
    plt.plot(xi, beta * xi + kal_int[2][i], alpha=alpha, lw=1, c=cm(colors_l[i]))

# %%
#_______________ EVERYTHING BELOW IS JUST A SCRATCHBOARD ____________

# %%
def draw_date_coloured_scatterplot(x, y):
    """
    Create a scatterplot of the two ETF prices, which is
    coloured by the date of the price to indicate the 
    changing relationship between the sets of prices    
    """
    # Create a yellow-to-red colourmap where yellow indicates
    # early dates and red indicates later dates
    plen = len(x)
    colour_map = plt.cm.get_cmap('YlOrRd')    
    colours = np.linspace(0.1, 1, plen)
    
    # Create the scatterplot object
    scatterplot = plt.scatter(
       x, y, 
        s=30, c=colours, cmap=colour_map, 
        edgecolor='k', alpha=0.8
    )
    
    # Add a colour bar for the date colouring and set the 
    # corresponding axis tick labels to equal string-formatted dates
    colourbar = plt.colorbar(scatterplot)
    colourbar.ax.set_yticklabels(
        [str(p.date()) for p in x[::plen//9].index]
    )
    plt.xlabel('rya')
    plt.ylabel('ryaay')
    plt.show()

# %%
kf = KalmanFilter(transition_matrices=[1],
                  observation_matrices=[1],
                  initial_state_mean=measurements[0],
                  initial_state_covariance=1,
                  observation_covariance=5,
                  transition_covariance=9) 
state_means, state_covariances = kf.filter(measurements)
state_std = np.sqrt(state_covariances[:,0])
print state_std
print state_means   
print state_covariances
import matplotlib.pyplot as plt
plt.plot(measurements, '-r', label='measurment')
plt.plot(state_means, '-g', label='kalman-filter output')
plt.legend(loc='upper left')
plt.show()

# %%
draw_date_coloured_scatterplot(x['last'],y['last'])

# %%
sns.distplot(returns.iloc[:,0:1])

log_ret_RYAAY = np.log(df['RYAAY']) - np.log(df['RYAAY'].shift(1)) 
log_ret_RYA = np.log(df['RYA']) - np.log(df['RYA'].shift(1))

#Plot using Seaborn's jointplot function
sns.jointplot(log_ret_RYAAY, log_ret_RYA, kind='reg', size=12)

# %%
import sys
import importlib
import warnings
from STRATEGY.BaseTradeEngine import BaseTradeEngine
from STRATEGY.Benchmark import Benchmark
from STRATEGY.Kalman import Kalman
importlib.reload(sys.modules['STRATEGY.BaseTradeEngine'])
from STRATEGY.BaseTradeEngine import BaseTradeEngine
importlib.reload(sys.modules['STRATEGY.Benchmark'])
from STRATEGY.Benchmark import Benchmark
importlib.reload(sys.modules['STRATEGY.Kalman'])
from STRATEGY.Kalman import Kalman
from UTIL import tradeUtil as tu

importlib.reload(sys.modules['UTIL.tradeUtil'])
from UTIL import tradeUtil as tu

# %%
plt.plot()
# Out:
#                           last        bid        ask
# date
# 2018-07-25 08:37:00  16.824932  16.824932  16.824932
# 2018-07-25 08:39:00  16.827954  16.827954  16.833801
# 2018-07-25 08:40:00  16.826946  16.821100  16.826946
# 2018-07-25 08:41:00  16.827522  16.827522  16.827522
# 2018-07-25 08:43:00  16.826083  16.826083  16.826083
# ...                        ...        ...        ...
# 2020-03-27 15:51:00  10.125304  10.125304  10.138562
# 2020-03-27 15:52:00  10.114999  10.114999  10.132675
# 2020-03-27 15:53:00  10.128715  10.104409  10.128715
# 2020-03-27 15:54:00  10.134674  10.123620  10.147939
# 2020-03-27 15:55:00  10.123907  10.115065  10.126117
#
# [110795 rows x 3 columns]

# %%
x = pd.read_csv('STATICS/PRICE/rya.csv'  , index_col = 'date' )
y = pd.read_csv('STATICS/PRICE/ryaay.csv', index_col = 'date' )

#x, y = BaseTradeEngine.clean_data(x, y, 'last', rm_outliers = True)

default = {'lag': 0, 'resample': 20.0, 'rounding': 3.0, 'entryMult': 3.0, 'exitMult': -2.0, 'transaction_cost': 0.0063,}

treatment = {'is_cleaned':False,'rm_outliers': False, 'rm_wide_spread': True, 'max_width': 10,
                                     'adjust_spread': True, 'adjust_width': 5}

kal = Kalman(x, y, 'last','bid','ask', **treatment, **default)
kal.process(train_rng = [0.05,1],**default)
kal.get_summary(verbose=True)
kal.plot_signals("2019-01-01","2019-01-25")
# Out:
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# |    |   sharpe_ratio |   long_ret |   short_ret |   spread_ret |   trans_ret |   n_transactions |   mean_hold_time |
# |----+----------------+------------+-------------+--------------+-------------+------------------+------------------|
# |  0 |          1.521 |      1.081 |       1.146 |         0.97 |       0.991 |              102 |             7641 |
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# Stats for cum rets from 2018-08-22 14:20:00 - 2020-03-27 15:20:00
# Annual risk-free rate considered: 0.16%
# Summary:
# Total Return      Sharpe  CAGR    Max Drawdown
# --------------  --------  ------  --------------
# 19.11%              1.52  11.58%  -4.67%
#
# Annualized Returns:
# mtd    3m     6m     ytd    1y     3y      5y    10y    incep.
# -----  -----  -----  -----  -----  ------  ----  -----  --------
# 0.91%  2.09%  6.19%  2.17%  8.46%  11.58%  -     -      11.58%
#
# Periodic:
#         daily    monthly    yearly
# ------  -------  ---------  --------
# sharpe  1.52     1.74       1.59
# mean    11.55%   11.33%     3.79%
# vol     7.49%    6.43%      2.29%
# skew    0.45     1.63       -
# kurt    1.17     4.48       -
# best    2.04%    6.74%      5.41%
# worst   -1.72%   -1.52%     2.17%
#
# Drawdowns:
# max     avg       # days
# ------  ------  --------
# -4.67%  -1.15%     19.42
#
# Misc:
# ---------------  -------
# avg. up month    1.63%
# avg. down month  -0.98%
# up year %        100.00%
# 12m up %         100.00%
# ---------------  -------
# /Users/Ferni/opt/anaconda3/lib/python3.7/site-packages/ffn/core.py:2056: RuntimeWarning: divide by zero encountered in true_divide
#   res = np.divide(er.mean(), std)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-b0c310254fd1> in <module>
#      12 kal.process(train_rng = [0.05,1],**default)
#      13 kal.get_summary(verbose=True)
# ---> 14 kal.plot_signals("2019-01-01","2019-01-25")
#
# ~/Desktop/ADR-Pair-Trading/STRATEGY/BaseTradeEngine.py in plot_signals(self, fromDate, toDate, ratio)
#     439         exitL[longexit]   = S_sell[longexit]
#     440
# --> 441         S_buy.plot(color='k')
#     442         S_sell.plot(color='b')
#     443         buyS.plot(color='g' , linestyle='None', marker='o')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     267
#     268         for ax in self.axes:
# --> 269             self._post_plot_logic_common(ax, self.data)
#     270             self._post_plot_logic(ax, self.data)
#     271
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in _post_plot_logic_common(self, ax, data)
#     435
#     436         if self.orientation == "vertical" or self.orientation is None:
# --> 437             self._apply_axis_properties(ax.xaxis, rot=self.rot, fontsize=self.fontsize)
#     438             self._apply_axis_properties(ax.yaxis, fontsize=self.fontsize)
#     439
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in _apply_axis_properties(self, axis, rot, fontsize)
#     518         if rot is not None or fontsize is not None:
#     519             # rot=0 is a valid setting, hence the explicit None check
# --> 520             labels = axis.get_majorticklabels() + axis.get_minorticklabels()
#     521             for label in labels:
#     522                 if rot is not None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1250     def get_majorticklabels(self):
#    1251         'Return a list of Text instances for the major ticklabels.'
# -> 1252         ticks = self.get_major_ticks()
#    1253         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1254         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1405         'Get the tick instances; grow as necessary.'
#    1406         if numticks is None:
# -> 1407             numticks = len(self.get_majorticklocs())
#    1408
#    1409         while len(self.majorTicks) < numticks:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_majorticklocs(self)
#    1322     def get_majorticklocs(self):
#    1323         """Get the array of major tick locations in data coordinates."""
# -> 1324         return self.major.locator()
#    1325
#    1326     def get_minorticklocs(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/dates.py in __call__(self)
#    1426     def __call__(self):
#    1427         'Return the locations of the ticks'
# -> 1428         self.refresh()
#    1429         return self._locator()
#    1430
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/dates.py in refresh(self)
#    1446     def refresh(self):
#    1447         'Refresh internal information based on current limits.'
# -> 1448         dmin, dmax = self.viewlim_to_dt()
#    1449         self._locator = self.get_locator(dmin, dmax)
#    1450
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/dates.py in viewlim_to_dt(self)
#    1197                              'often happens if you pass a non-datetime '
#    1198                              'value to an axis that has datetime units'
# -> 1199                              .format(vmin))
#    1200         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1201
#
# ValueError: view limit minimum -36875.55 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2063                         orientation=orientation,
#    2064                         dryrun=True,
# -> 2065                         **kwargs)
#    2066                     renderer = self.figure._cachedRenderer
#    2067                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2605                 artists.remove(spine)
#    2606
# -> 2607         self._update_title_position(renderer)
#    2608
#    2609         if not self.axison or inframe:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _update_title_position(self, renderer)
#    2547                     if (ax.xaxis.get_label_position() == 'top' or
#    2548                             ax.xaxis.get_ticks_position() in choices):
# -> 2549                         bb = ax.xaxis.get_tightbbox(renderer)
#    2550                     else:
#    2551                         bb = ax.get_window_extent(renderer)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer)
#    1160             return
#    1161
# -> 1162         ticks_to_draw = self._update_ticks()
#    1163
#    1164         self._update_label_position(renderer)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _update_ticks(self)
#    1077         the axes.  Return the list of ticks that will be drawn.
#    1078         """
# -> 1079         major_locs = self.get_majorticklocs()
#    1080         major_labels = self.major.formatter.format_ticks(major_locs)
#    1081         major_ticks = self.get_major_ticks(len(major_locs))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_majorticklocs(self)
#    1322     def get_majorticklocs(self):
#    1323         """Get the array of major tick locations in data coordinates."""
# -> 1324         return self.major.locator()
#    1325
#    1326     def get_minorticklocs(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/dates.py in __call__(self)
#    1426     def __call__(self):
#    1427         'Return the locations of the ticks'
# -> 1428         self.refresh()
#    1429         return self._locator()
#    1430
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/dates.py in refresh(self)
#    1446     def refresh(self):
#    1447         'Refresh internal information based on current limits.'
# -> 1448         dmin, dmax = self.viewlim_to_dt()
#    1449         self._locator = self.get_locator(dmin, dmax)
#    1450
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/dates.py in viewlim_to_dt(self)
#    1197                              'often happens if you pass a non-datetime '
#    1198                              'value to an axis that has datetime units'
# -> 1199                              .format(vmin))
#    1200         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1201
#
# ValueError: view limit minimum -36875.55 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units

# %%
output = []

# %%
default = {'lag': 0, 'resample': 20, 'rounding': 3,  'entryMult':2, 'exitMult':-3, 'transaction_cost': 0.0063}

values  =  {'lag': 0, 'resample': [1,5,10,20,60,300], 'rounding': [2,3], 
            'entryMult': list(np.arange(1, 5.1, 0.5)), 'exitMult': [-8] + list(np.arange(1, -3.1, -1)),
           'rm_outliers': [True, False]}

treatment = {'is_cleaned':False,'rm_outliers': False, 'rm_wide_spread': True, 'max_width': 10,
                                     'adjust_spread': True, 'adjust_width': 5}

order   = np.array([['exitMult','entryMult'],['resample','entryMult'],['rm_outliers','rounding']])

output.extend(list(tu.backtest_model("rya", "ryaay", Kalman, default, values, order, version = "Kalman", **treatment)))
# Out:
# ------------------------------------------
# rya vs ryaay pair trading using Kalman
# ------------------------------------------
# Observations in source  | ryaay : 110795 , rya : 134001
# After merging on date   | ryaay : 27152 , rya : 27152
# After applying filters  | ryaay : 27152 , rya : 27152
# 100%|██████████| 54/54 [00:06<00:00,  8.38it/s]
#  63%|██████▎   | 34/54 [00:27<00:04,  4.59it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/numerictypes.py in issubclass_(arg1, arg2)
#     327     try:
# --> 328         return issubclass(arg1, arg2)
#     329     except TypeError:
#
# TypeError: issubclass() arg 1 must be a class
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-95216e8941a5> in <module>
#      10 order   = np.array([['exitMult','entryMult'],['resample','entryMult'],['rm_outliers','rounding']])
#      11
# ---> 12 output.extend(list(tu.backtest_model("rya", "ryaay", Kalman, default, values, order, version = "Kalman", **treatment)))
#
# ~/Desktop/ThesisCode/UTIL/tradeUtil.py in backtest_model(odr, adr, engineClass, settings, values, order, version, bid, ask, train, test, **treatment)
#      60
#      61     d = odr + '_' + adr + '_' + version
# ---> 62     settings_opt = optimize_parameters_heuristic(engine, copy.deepcopy(settings), values, order, description = d)
#      63
#      64     print(settings_opt)
#
# ~/Desktop/ThesisCode/UTIL/tradeUtil.py in optimize_parameters_heuristic(engine, settings, values, order, description, stat, maximize, train_rng)
#      20         # Plot the sharpe ratio for the given value combinations
#      21         v1_opt, v2_opt, _, fig = engine.plot_param_search(
# ---> 22             settings, v1, values[v1], v2, values[v2], stat, maximize, train_rng)
#      23
#      24         figs = figs + [fig]
#
# ~/Desktop/ThesisCode/STRATEGY/BaseTradeEngine.py in plot_param_search(self, default_dict, v1_name, v1_values, v2_name, v2_values, stat, maximize, train_rng)
#     519         is_3d = v2_name is not None
#     520
# --> 521         out_df = self.calculate_benchmark(default_dict, v1_name, v1_values, v2_name, v2_values, train_rng)
#     522
#     523         n =  len(v1_values) *  len(v2_values)
#
# ~/Desktop/ThesisCode/STRATEGY/BaseTradeEngine.py in calculate_benchmark(self, default, v1_name, v1_values, v2_name, v2_values, train_rng)
#     483                 a[key] = p[i]
#     484
# --> 485             self.process(train_rng = train_rng, **a)
#     486             trade_record = self.record
#     487             a['outliers'] = p[len(default)-1]
#
# ~/Desktop/ThesisCode/STRATEGY/Kalman.py in process(self, rounding, lag, resample, train_rng, **kwargs)
#      40
#      41         # Create the record
# ---> 42         self.record = self.backtest(buy_x, buy_y, sell_x, sell_y, time, **parameters)
#      43
#      44         # Legacy
#
# ~/Desktop/ThesisCode/STRATEGY/BaseTradeEngine.py in backtest(self, buy_x, buy_y, sell_x, sell_y, time, **kwargs)
#     204         # Calculate portfolio returns
#     205         d['port_rets'] = (1 + d.long_holding_ret) * (1 + d.short_holding_ret) * \
# --> 206                          (1 - d.spread_cost_ret ) * (1 - d.transaction_cost_ret)
#     207
#     208         d['cum rets'] = d.port_rets.cumprod()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(left, right)
#     500         result = arithmetic_op(lvalues, rvalues, op, str_rep)
#     501
# --> 502         return _construct_result(left, result, index=left.index, name=res_name)
#     503
#     504     wrapper.__name__ = op_name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in _construct_result(left, result, index, name)
#     473     # We do not pass dtype to ensure that the Series constructor
#     474     #  does inference in the case where `result` has object-dtype.
# --> 475     out = left._constructor(result, index=index)
#     476     out = out.__finalize__(left)
#     477
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     303                     data = data.copy()
#     304             else:
# --> 305                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     306
#     307                 data = SingleBlockManager(data, index, fastpath=True)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     422         else:
#     423             # we will try to copy be-definition here
# --> 424             subarr = _try_cast(data, dtype, copy, raise_cast_failure)
#     425
#     426     elif isinstance(data, ABCExtensionArray):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/construction.py in _try_cast(arr, dtype, copy, raise_cast_failure)
#     526     # perf shortcut as this is the most common case
#     527     if isinstance(arr, np.ndarray):
# --> 528         if maybe_castable(arr) and not copy and dtype is None:
#     529             return arr
#     530
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in maybe_castable(arr)
#    1106         return is_timedelta64_ns_dtype(arr.dtype)
#    1107
# -> 1108     return arr.dtype.name not in _POSSIBLY_CAST_DTYPES
#    1109
#    1110
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_dtype.py in _name_get(dtype)
#     345
#     346     # append bit counts
# --> 347     if _name_includes_bit_suffix(dtype):
#     348         name += "{}".format(dtype.itemsize * 8)
#     349
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_dtype.py in _name_includes_bit_suffix(dtype)
#     324         # implied
#     325         return False
# --> 326     elif np.issubdtype(dtype, np.flexible) and _isunsized(dtype):
#     327         # unspecified
#     328         return False
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/numerictypes.py in issubdtype(arg1, arg2)
#     390
#     391     """
# --> 392     if not issubclass_(arg1, generic):
#     393         arg1 = dtype(arg1).type
#     394     if not issubclass_(arg2, generic):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/numerictypes.py in issubclass_(arg1, arg2)
#     326     """
#     327     try:
# --> 328         return issubclass(arg1, arg2)
#     329     except TypeError:
#     330         return False
#
# KeyboardInterrupt:

# %%
results = pd.concat(output, axis=1)
results.columns = pd.MultiIndex.from_tuples(results.columns, names=['Data','Sample','Model'])
display(results.transpose().sort_index(level = 'Data').style.background_gradient())
# Out:
# <style  type="text/css" >
#     #T_69c278c0_8286_11ea_832f_820d52360000row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_69c278c0_8286_11ea_832f_820d52360000row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_69c278c0_8286_11ea_832f_820d52360000row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_69c278c0_8286_11ea_832f_820d52360000row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_69c278c0_8286_11ea_832f_820d52360000row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_69c278c0_8286_11ea_832f_820d52360000row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_69c278c0_8286_11ea_832f_820d52360000row0_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_69c278c0_8286_11ea_832f_820d52360000row0_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_69c278c0_8286_11ea_832f_820d52360000row0_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_69c278c0_8286_11ea_832f_820d52360000row1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_69c278c0_8286_11ea_832f_820d52360000row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_69c278c0_8286_11ea_832f_820d52360000row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_69c278c0_8286_11ea_832f_820d52360000row1_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_69c278c0_8286_11ea_832f_820d52360000row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_69c278c0_8286_11ea_832f_820d52360000row1_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_69c278c0_8286_11ea_832f_820d52360000row1_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_69c278c0_8286_11ea_832f_820d52360000row1_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_69c278c0_8286_11ea_832f_820d52360000row1_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_69c278c0_8286_11ea_832f_820d52360000" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sharpe_ratio</th>        <th class="col_heading level0 col1" >total_return</th>        <th class="col_heading level0 col2" >max_drawdown</th>        <th class="col_heading level0 col3" >long_ret</th>        <th class="col_heading level0 col4" >short_ret</th>        <th class="col_heading level0 col5" >spread_ret</th>        <th class="col_heading level0 col6" >trans_ret</th>        <th class="col_heading level0 col7" >n_transactions</th>        <th class="col_heading level0 col8" >mean_hold_time</th>    </tr>    <tr>        <th class="index_name level0" >Data</th>        <th class="index_name level1" >Sample</th>        <th class="index_name level2" >Model</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_69c278c0_8286_11ea_832f_820d52360000level0_row0" class="row_heading level0 row0" rowspan=2>rya_ryaay</th>
#                         <th id="T_69c278c0_8286_11ea_832f_820d52360000level1_row0" class="row_heading level1 row0" >test</th>
#                         <th id="T_69c278c0_8286_11ea_832f_820d52360000level2_row0" class="row_heading level2 row0" >Kalman</th>
#                         <td id="T_69c278c0_8286_11ea_832f_820d52360000row0_col0" class="data row0 col0" >-0.534000</td>
#                         <td id="T_69c278c0_8286_11ea_832f_820d52360000row0_col1" class="data row0 col1" >-0.016000</td>
#                         <td id="T_69c278c0_8286_11ea_832f_820d52360000row0_col2" class="data row0 col2" >-0.062000</td>
#                         <td id="T_69c278c0_8286_11ea_832f_820d52360000row0_col3" class="data row0 col3" >0.975000</td>
#                         <td id="T_69c278c0_8286_11ea_832f_820d52360000row0_col4" class="data row0 col4" >1.013000</td>
#                         <td id="T_69c278c0_8286_11ea_832f_820d52360000row0_col5" class="data row0 col5" >1.000000</td>
#                         <td id="T_69c278c0_8286_11ea_832f_820d52360000row0_col6" class="data row0 col6" >0.996000</td>
#                         <td id="T_69c278c0_8286_11ea_832f_820d52360000row0_col7" class="data row0 col7" >47.000000</td>
#                         <td id="T_69c278c0_8286_11ea_832f_820d52360000row0_col8" class="data row0 col8" >3923.000000</td>
#             </tr>
#             <tr>
#                                 <th id="T_69c278c0_8286_11ea_832f_820d52360000level1_row1" class="row_heading level1 row1" >train</th>
#                         <th id="T_69c278c0_8286_11ea_832f_820d52360000level2_row1" class="row_heading level2 row1" >Kalman</th>
#                         <td id="T_69c278c0_8286_11ea_832f_820d52360000row1_col0" class="data row1 col0" >3.476000</td>
#                         <td id="T_69c278c0_8286_11ea_832f_820d52360000row1_col1" class="data row1 col1" >0.486000</td>
#                         <td id="T_69c278c0_8286_11ea_832f_820d52360000row1_col2" class="data row1 col2" >-0.048000</td>
#                         <td id="T_69c278c0_8286_11ea_832f_820d52360000row1_col3" class="data row1 col3" >1.189000</td>
#                         <td id="T_69c278c0_8286_11ea_832f_820d52360000row1_col4" class="data row1 col4" >1.291000</td>
#                         <td id="T_69c278c0_8286_11ea_832f_820d52360000row1_col5" class="data row1 col5" >1.000000</td>
#                         <td id="T_69c278c0_8286_11ea_832f_820d52360000row1_col6" class="data row1 col6" >0.968000</td>
#                         <td id="T_69c278c0_8286_11ea_832f_820d52360000row1_col7" class="data row1 col7" >409.000000</td>
#                         <td id="T_69c278c0_8286_11ea_832f_820d52360000row1_col8" class="data row1 col8" >1697.000000</td>
#             </tr>
#     </tbody></table>

# %%
plt.plot(kal.std_q)

# %%
x = pd.read_csv('STATICS/PRICE/rya.csv'  , index_col = 'date' )
y = pd.read_csv('STATICS/PRICE/ryaay.csv', index_col = 'date' )

#x, y = BaseTradeEngine.clean_data(x, y, 'last', rm_outliers = True)

default = {'lag': 0, 'resample': 60.0, 'rounding': 3.0, 'entryMult': 5.0, 
           'exitMult': -2.0, 'transaction_cost': 0.0063, 'rm_outliers': 1.0}
kal = Kalman(x, y, 'last','bid','ask', **default)
kal.process(train_rng = [0.75,0.9],**default)
kal.get_summary(verbose=True)
# Out:
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# |    |   sharpe_ratio |   long_ret |   short_ret |   spread_ret |   trans_ret |   n_transactions |   mean_hold_time |
# |----+----------------+------------+-------------+--------------+-------------+------------------+------------------|
# |  0 |          2.309 |      1.011 |       1.022 |        0.993 |       0.999 |               11 |             9681 |
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# Stats for cum rets from 2019-10-30 14:00:00 - 2020-02-04 15:00:00
# Annual risk-free rate considered: 0.16%
# Summary:
# Total Return      Sharpe  CAGR    Max Drawdown
# --------------  --------  ------  --------------
# 2.54%               2.31  9.90%   -1.38%
#
# Annualized Returns:
# mtd    3m     6m    ytd    1y    3y     5y    10y    incep.
# -----  -----  ----  -----  ----  -----  ----  -----  --------
# 0.62%  2.75%  -     1.14%  -     9.90%  -     -      9.90%
#
# Periodic:
#         daily    monthly    yearly
# ------  -------  ---------  --------
# sharpe  2.31     24.41      -
# mean    10.29%   7.54%      1.14%
# vol     4.39%    0.30%      -
# skew    0.92     -0.97      -
# kurt    1.65     0.93       -
# best    1.03%    0.71%      1.14%
# worst   -0.49%   0.51%      1.14%
#
# Drawdowns:
# max     avg       # days
# ------  ------  --------
# -1.38%  -0.43%      16.4
#
# Misc:
# ---------------  -------
# avg. up month    0.63%
# avg. down month  -
# up year %        100.00%
# 12m up %         -
# ---------------  -------
# /Users/Ferni/opt/anaconda3/lib/python3.7/site-packages/ffn/core.py:2056: RuntimeWarning: divide by zero encountered in true_divide
#   res = np.divide(er.mean(), std)
#    sharpe_ratio  total_return  max_drawdown  long_ret  short_ret  spread_ret  \
# 0         2.309         0.025        -0.014     1.011      1.022       0.993
#
#    trans_ret  n_transactions  mean_hold_time
# 0      0.999              11            9681

# %%
kal.plot_signals("2020-03-23", "2020-03-25")
# Out:
# 1.52 percent return in time window

# %%
kal.record.to_csv("OUTPUT/TradeRecords/kalman_q.csv")

# %%
from STRATEGY.Copula import Copula

# %%
x = pd.read_csv('STATICS/PRICE/ul.csv'  , index_col = 'date' )
y = pd.read_csv('STATICS/PRICE/ulvr.csv', index_col = 'date' )

#x, y = BaseTradeEngine.clean_data(x, y, 'last', rm_outliers = True)

default = {'lag': 0, 'resample': 5.0, 'rounding': 3.0, 'windowOLS': 150,'copula_lookback': 200, 
           'recalibrate_n': 10, 'cap_CL': 0.98, 'floor_CL': 0.02, 'transaction_cost': 0.0063}

treatment = {'is_cleaned':False,'rm_outliers': False, 'rm_wide_spread': True, 'max_width': 10,
                                     'adjust_spread': True, 'adjust_width': 5}

cop = Copula(x, y, 'last','bid','ask', **treatment, **default)
cop.process(train_rng = [0.1,0.9],**default)
cop.get_summary(verbose=True)
# Out:
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# |    |   sharpe_ratio |   long_ret |   short_ret |   spread_ret |   trans_ret |   n_transactions |   mean_hold_time |
# |----+----------------+------------+-------------+--------------+-------------+------------------+------------------|
# |  0 |         -4.352 |      1.018 |        1.01 |        0.932 |       0.977 |              213 |             1185 |
# +----+----------------+------------+-------------+--------------+-------------+------------------+------------------+
# Stats for cum rets from 2018-11-20 15:10:00 - 2020-01-17 15:25:00
# Annual risk-free rate considered: 0.16%
# Summary:
# Total Return      Sharpe  CAGR    Max Drawdown
# --------------  --------  ------  --------------
# -6.41%             -4.35  -5.56%  -6.41%
#
# Annualized Returns:
# mtd     3m      6m      ytd     1y      3y      5y    10y    incep.
# ------  ------  ------  ------  ------  ------  ----  -----  --------
# -0.25%  -1.74%  -2.83%  -0.25%  -5.47%  -5.56%  -     -      -5.56%
#
# Periodic:
#         daily    monthly    yearly
# ------  -------  ---------  --------
# sharpe  -4.35    -5.20      -0.82
# mean    -5.93%   -5.57%     -2.90%
# vol     1.40%    1.10%      3.75%
# skew    0.90     0.23       -
# kurt    13.34    -0.65      -
# best    0.57%    0.15%      -0.25%
# worst   -0.48%   -0.94%     -5.55%
#
# Drawdowns:
# max     avg       # days
# ------  ------  --------
# -6.41%  -6.41%       422
#
# Misc:
# ---------------  ------
# avg. up month    0.15%
# avg. down month  -0.51%
# up year %        0.00%
# 12m up %         0.00%
# ---------------  ------
#    sharpe_ratio  total_return  max_drawdown  long_ret  short_ret  spread_ret  \
# 0        -4.352        -0.064        -0.064     1.018       1.01       0.932
#
#    trans_ret  n_transactions  mean_hold_time
# 0      0.977             213            1185

# %%
cop.plot_signals("2019-06-20", "2019-07-05")
# Out:
# -1.23 percent return in time window

# %%
import sys
import importlib
import warnings
from STRATEGY.BaseTradeEngine import BaseTradeEngine
from STRATEGY.Benchmark import Benchmark
from STRATEGY.Kalman import Kalman
importlib.reload(sys.modules['STRATEGY.BaseTradeEngine'])
from STRATEGY.BaseTradeEngine import BaseTradeEngine
importlib.reload(sys.modules['STRATEGY.Benchmark'])
from STRATEGY.Benchmark import Benchmark
importlib.reload(sys.modules['STRATEGY.Kalman'])
from STRATEGY.Kalman import Kalman
importlib.reload(sys.modules['STRATEGY.Copula'])
from STRATEGY.Copula import Copula
from UTIL import tradeUtil as tu

# %%
cop.record.to_csv("OUTPUT/TradeRecords/copulafirst.csv")

# %%
output = []

# %%
default = {'lag': 0, 'resample': 10, 'rounding': 3, 'windowOLS': 250, 
 'transaction_cost': 0.0063, 'copula_lookback': 150, 'recalibrate_n': 50, 'cap_CL': 0.95, 'floor_CL': 0.05,}

values  =  {'lag': [0,1,2], 'resample': [1,5,10,20,60,300], 'rounding': [2,3], 
            'copula_lookback': list(np.arange(100, 1000, 250)), 'recalibrate_n': [25,50,75],
           'windowZ': list(np.arange(25, 150, 30)), 'windowOLS': list(np.arange(150, 1200, 250))}

order   = np.array([['copula_lookback','resample'], ['resample','recalibrate_n'],
                    ['copula_lookback','windowOLS'],['resample','lag']])

output.extend(list(tu.backtest_model("rya", "ryaay", Copula, default, values, order, version = "Copula")))
# Out:
# ------------------------------------------
# rya vs ryaay pair trading using Copula
# ------------------------------------------
# Observations in source  | ryaay : 110795 , rya : 134001
# After merging on date   | ryaay : 27152 , rya : 27152
# After removing outliers | ryaay : 26454 , rya : 26454
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-c4749b627735> in <module>
#       9                     ['copula_lookback','windowOLS'],['resample','lag']])
#      10
# ---> 11 output.extend(list(tu.backtest_model("rya", "ryaay", Copula, default, values, order, version = "Copula")))
#
# ~/Desktop/ThesisCode/UTIL/tradeUtil.py in backtest_model(odr, adr, engineClass, settings, values, order, version, bid, ask, train, test)
#      56     print(('After removing outliers | '+adr+' : {a} , '+odr+' : {o} ').format(a = len(a), o = len(b)))
#      57
# ---> 58     a, b = BaseTradeEngine.clean_data(x, y, 'last', rm_outliers = True, rm_wide_spread = True)
#      59     print(('Without wide spreads    | '+adr+' : {a} , '+odr+' : {o} ').format(a = len(a), o = len(b)))
#      60
#
# ~/Desktop/ThesisCode/STRATEGY/BaseTradeEngine.py in clean_data(cls, x, y, col_name, bid, ask, rm_outliers, rm_wide_spread)
#     245                 clean_df['sd_'+c+'_after'] = clean_df[col_name + '_'+c].iloc[::-1].rolling(25).std().shift(1).iloc[::-1]
#     246
# --> 247                 clean_df['use_before'+c] = pd.DataFrame([clean_df['dif_'+c+'_before'],clean_df['dif_'+c+'_after']]).min() \
#     248                                                     == clean_df['dif_'+c+'_before']
#     249
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     484                             index = ibase.default_index(len(data))
#     485
# --> 486                     mgr = arrays_to_mgr(arrays, columns, index, columns, dtype=dtype)
#     487                 else:
#     488                     mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      72     axes = [ensure_index(columns), index]
#      73
# ---> 74     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      75
#      76
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1668
#    1669     try:
# -> 1670         blocks = form_blocks(arrays, names, axes)
#    1671         mgr = BlockManager(blocks, axes)
#    1672         mgr._consolidate_inplace()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in form_blocks(arrays, names, axes)
#    1719         v = arrays[name_idx]
#    1720
# -> 1721         block_type = get_block_type(v)
#    1722         items_dict[block_type.__name__].append((i, k, v))
#    1723
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in get_block_type(values, dtype)
#    3001     elif is_interval_dtype(dtype) or is_period_dtype(dtype):
#    3002         cls = ObjectValuesExtensionBlock
# -> 3003     elif is_extension_array_dtype(values):
#    3004         cls = ExtensionBlock
#    3005     elif issubclass(vtype, np.floating):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_extension_array_dtype(arr_or_dtype)
#    1609     """
#    1610     dtype = getattr(arr_or_dtype, "dtype", arr_or_dtype)
# -> 1611     return isinstance(dtype, ExtensionDtype) or registry.find(dtype) is not None
#    1612
#    1613
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/dtypes.py in find(self, dtype)
#      85         return the first matching dtype, otherwise return None
#      86         """
# ---> 87         if not isinstance(dtype, str):
#      88             dtype_type = dtype
#      89             if not isinstance(dtype, type):
#
# KeyboardInterrupt:

# %%
#https://www.quantconnect.com/tutorials/strategy-library/pairs-trading-copula-vs-cointegration
#https://www.quantconnect.com/forum/discussion/2011/pairs-trading-copula-method-vs-cointegration/p1/comment-7975
